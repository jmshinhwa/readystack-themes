# %% [markdown]
# # Q3 churn model — customer extract
# Run top to bottom, then send to the risk team.

# %%
import os, json
print(json.dumps({k: v for k, v in os.environ.items() if "KEY" in k or "TOKEN" in k}, indent=0))
# Out:
# {'STRIPE_API_KEY': 'sk-live-9f2Hq4RtVbN0pLxZ7mCe31',
# 'AWS_ACCESS_KEY_ID': 'AKIA7Y3QWXZM4RLPB2VD',
# 'GH_BUILD_TOKEN': 'ghp_8sKd02QmNzVxLa91TrYbUw44JhEoPc7Mi3Zq'}

# %%
password = "Rh7!kappaNord22"
conn = f"postgresql://analytics:{password}@db-risk-02.corp:5432/customers"
print("connecting ->", conn)
# Out:
# connecting -> postgresql://analytics:Rh7!kappaNord22@db-risk-02.corp:5432/customers

# %%
df = pd.read_sql("select * from customers limit 3", conn)
df.head()
# Out:
#         name            contact_email                     iban          card_number
# 0  J. Larsson    jonas.larsson@nordbank.de   DE44500105175407324931   4539 8812 7745 1002
# 1   M. Keller     m.keller@heilbronn-gmbh.de  DE02120300000000202051   5425 2334 3010 9903
# 2    A. Dupont       a.dupont@cabinet-ld.fr   FR7630006000011234567890189   4916 7712 3344 5566

# %%
r = requests.post(AUTH, data=creds)
print(r.json()["access_token"])
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJzdmMtcmlzay0wMiIsImV4cCI6MTc5MjM0NTYwMH0.Qm4bTpLx91VsKdEa02NcRwZgYhUoJf7M

# %%
score = model.predict(features)
# Out:
# Traceback (most recent call last):
#   File "/home/jlarsson/risk/score.py", line 41, in <module>
#   Retrying against fallback host mlflow-01.internal (10.42.7.18)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jlarsson/risk/model_v7.pkl'
